# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
df = pd.read_csv(os.getcwd()+'/raw_data/census.csv')

# %%
df.head(50)
# Out:
#     age          workclass   fnlgt      education   education-num  \
# 0    39          State-gov   77516      Bachelors              13
# 1    50   Self-emp-not-inc   83311      Bachelors              13
# 2    38            Private  215646        HS-grad               9
# 3    53            Private  234721           11th               7
# 4    28            Private  338409      Bachelors              13
# 5    37            Private  284582        Masters              14
# 6    49            Private  160187            9th               5
# 7    52   Self-emp-not-inc  209642        HS-grad               9
# 8    31            Private   45781        Masters              14
# 9    42            Private  159449      Bachelors              13
# 10   37            Private  280464   Some-college              10
# 11   30          State-gov  141297      Bachelors              13
# 12   23            Private  122272      Bachelors              13
# ...

# %%
df.describe()
# Out:
#                 age         fnlgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %%
columns_orig = list(df.columns.values)
print(columns_orig)
# Out:
# ['age', ' workclass', ' fnlgt', ' education', ' education-num', ' marital-status', ' occupation', ' relationship', ' race', ' sex', ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country', ' salary']

# %%
columns_new = [x.replace(' ','') for x in columns_orig]
print(columns_new)
# Out:
# ['age', 'workclass', 'fnlgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'salary']

# %%
df.columns = columns_new

# %%
def print_uniques(df,col_list):
    for col in col_list:
        print(df[col].value_counts())

# %%
col_list = df.select_dtypes(include=['object']).columns.tolist()

# %%
type(col_list)
# Out:
# list

# %%
col_list
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'salary']

# %%
print_uniques(df,col_list)
# Out:
#  workclass
# Private             22696
# Self-emp-not-inc     2541
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: count, dtype: int64
#  education
# HS-grad         10501
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# 11th             1175
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# 12th              433
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: count, dtype: int64
#  marital-status
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: count, dtype: int64
# ...

# %%
def data_cleaning(df, col_list):
    # run replace
    df_replace = df.copy()
    for col in col_list:
        
        df_replace[col] = df_replace[col].str.strip().replace('?','unknown')
    return df_replace

# %%
df_new = data_cleaning(df,col_list)

# %%
replace_dict = {' ': '', '?': np.nan}

# %%
for key, value in replace_dict.items():
    print(key,value)
# Out:
#
# ? nan

# %%
print(test)

# %%
df_new.head(20)
# Out:
#     age         workclass   fnlgt     education  education-num  \
# 0    39         State-gov   77516     Bachelors             13
# 1    50  Self-emp-not-inc   83311     Bachelors             13
# 2    38           Private  215646       HS-grad              9
# 3    53           Private  234721          11th              7
# 4    28           Private  338409     Bachelors             13
# 5    37           Private  284582       Masters             14
# 6    49           Private  160187           9th              5
# 7    52  Self-emp-not-inc  209642       HS-grad              9
# 8    31           Private   45781       Masters             14
# 9    42           Private  159449     Bachelors             13
# 10   37           Private  280464  Some-college             10
# 11   30         State-gov  141297     Bachelors             13
# 12   23           Private  122272     Bachelors             13
# 13   32           Private  205019    Assoc-acdm             12
# ...

# %%
os.getcwd()
# Out:
# '/mnt/e/ds/app_project'

# %%
file_path = os.path.join(os.getcwd(), 'data_clean')
file_name = 'census_clean.csv'

# %%
print(file_path)
# Out:
# /mnt/e/ds/app_project/data_clean

# %%
os.makedirs(file_path, exist_ok=True)

# %%
df_new.to_csv(os.path.join(file_path, file_name), index=False)
